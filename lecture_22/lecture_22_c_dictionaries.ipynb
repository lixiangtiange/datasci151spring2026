# %% [markdown]
# <font size = "4">
#
# - To get familiar with how operations on Pandas DataFrames work, it can be easier to test things out on "toy" DataFrames.
#
# - The easiest way to create a small test DataFrame is to define it using a **dictionary**
#
# - Dictionaries are another Python structure that can hold multiple objects - like lists or Numpy arrays

# %% [markdown]
# <font size = "4">
#
# Consider the following example:
#
# - We are keeping track of the course grades for a small class of 5 students.
# - We decide to use Python lists, which are indexed by the integers 0, 1, 2, ...
# - We need two lists: one for the student names, one for their grades.

# %%
student_roster = ["Nancy", "Bill", "Elaine", "Boris", "Assata"]
student_grades = [92.8, 87.3, 95.4, 82.3, 98.7]

# %% [markdown]
# <font size = "4">
#
# - Suppose "Boris" does some extra credit and we want to increase his grade to 85.
# - There's only 5 students, so we can quickly see that we need to change ``student_grades[3]``
# - But with a larger class, we would want to do this with Python commands, not manually.
#
# So, if we want to change the grade of "Boris" to 85, we could do:

# %%
b_index = student_roster.index("Boris") # find index

student_grades[b_index] = 85 # update corresponding element

print(student_grades)

# %% [markdown]
# <font size = "4">
#
# But a **dictionary** can be indexed with an integer or a string. We can directly use the students' names.

# %%
grades = {"Nancy" : 92.8, "Bill" : 87.3, "Elaine" : 95.4, "Boris": 82.3, "Assata" : 98.7}

print(grades["Boris"])

# %% [markdown]
# <font size = "4">
#
# We can change his Boris' grade easily:

# %%
grades["Boris"] = 85

# %%
print(grades)

# %% [markdown]
# <font size = "4">
#
# The indices for a dictionary are the **keys**, and the elements of the dictionary are the **values**

# %%
print(grades.keys())
print(grades.values())

# %%
for key in grades.keys():
    name = key 
    score = grades[key]
    print("Grade for", key, ":", score)

# %% [markdown]
# <font size = "4">
#
# Dictionaries can have strings and integers as keys. Items can be an object including lists (or other dictionaries)

# %%
example_dict = {0: "QTM-151", 
                "favorite movie" : "Evil Dead (2013)",
                12 : 35.2,
                "my_list" : [-8, 0.2, 9.1],
                "roster_from_above" : student_roster, 
                "dict_from_above": grades}

# keys
print(example_dict.keys())
print()

# values
print(example_dict[0])
print(example_dict["favorite movie"])
print(example_dict[12])
print(example_dict["my_list"])
print(example_dict["roster_from_above"])
print(example_dict["dict_from_above"])

# %% [markdown]
# <font size = "4">
#
# You can easily make small DataFrames using dictionaries.
#
# - The keys will be the column names of the DataFrame.
# - For each key, define the value as a list, which will be the entries of each column.
# - **Each list must have the same length.** Otherwise, you will get an error if you try to convert it to a DataFrame
#
# Below, we'll make a small DataFrame containing info for 5 U.S. states:

# %% [markdown]
# <font size = "4">
#
# We'll make another small DataFrame with different info for the same 5 states.

# %%
export default function PersonalWebsite() {
  return (
    <div className="min-h-screen bg-neutral-950 text-white">
      <section className="relative overflow-hidden">
        <div className="absolute inset-0 bg-[radial-gradient(circle_at_top_right,rgba(99,102,241,0.28),transparent_30%),radial-gradient(circle_at_left,rgba(34,211,238,0.18),transparent_28%),linear-gradient(to_bottom,rgba(255,255,255,0.02),rgba(255,255,255,0))]" />
        <div className="relative mx-auto max-w-6xl px-6 py-24 md:px-10 md:py-32">
          <nav className="mb-16 flex items-center justify-between">
            <div className="text-lg font-semibold tracking-tight">Xiangtiange Li</div>
            <div className="hidden gap-8 text-sm text-neutral-300 md:flex">
              <a href="#about" className="transition hover:text-white">About</a>
              <a href="#work" className="transition hover:text-white">Work</a>
              <a href="#projects" className="transition hover:text-white">Projects</a>
              <a href="#contact" className="transition hover:text-white">Contact</a>
            </div>
          </nav>

          <div className="grid items-center gap-12 md:grid-cols-[1.3fr_0.7fr]">
            <div>
              <div className="mb-4 inline-flex rounded-full border border-white/10 bg-white/5 px-4 py-2 text-xs uppercase tracking-[0.2em] text-neutral-300 backdrop-blur">
                Biology · Neuroscience · Data Science
              </div>
              <h1 className="max-w-4xl text-5xl font-semibold leading-tight tracking-tight md:text-7xl">
                Building at the intersection of
                <span className="bg-gradient-to-r from-cyan-300 via-blue-400 to-violet-400 bg-clip-text text-transparent"> biotech, neuro, and data</span>.
              </h1>
              <p className="mt-6 max-w-2xl text-lg leading-8 text-neutral-300 md:text-xl">
                I am Xiangtiange Li, a student and researcher exploring neuroscience, biotechnology, and computational approaches to real-world health problems.
              </p>
              <div className="mt-10 flex flex-wrap gap-4">
                <a
                  href="#projects"
                  className="rounded-2xl bg-white px-6 py-3 text-sm font-medium text-neutral-950 shadow-lg shadow-white/10 transition hover:-translate-y-0.5"
                >
                  View Projects
                </a>
                <a
                  href="#contact"
                  className="rounded-2xl border border-white/15 bg-white/5 px-6 py-3 text-sm font-medium text-white backdrop-blur transition hover:border-white/30 hover:bg-white/10"
                >
                  Get in Touch
                </a>
              </div>
            </div>

            <div className="rounded-[2rem] border border-white/10 bg-white/5 p-6 shadow-2xl shadow-cyan-950/20 backdrop-blur-xl">
              <div className="mb-4 text-sm text-neutral-400">Current Focus</div>
              <div className="space-y-4">
                {[
                  ["Neuroscience Research", "Brain signals, translational neurotech, and data-driven analysis."],
                  ["Biotech Exploration", "Molecular biology, therapeutics, and venture-facing biotech thinking."],
                  ["Computational Skills", "Statistics, modeling, and scientific storytelling."],
                ].map(([title, desc]) => (
                  <div key={title} className="rounded-2xl border border-white/10 bg-black/20 p-4">
                    <div className="font-medium">{title}</div>
                    <div className="mt-1 text-sm leading-6 text-neutral-400">{desc}</div>
                  </div>
                ))}
              </div>
            </div>
          </div>
        </div>
      </section>

      <main className="mx-auto max-w-6xl space-y-24 px-6 pb-24 md:px-10">
        <section id="about" className="grid gap-8 md:grid-cols-2">
          <div>
            <div className="mb-3 text-sm uppercase tracking-[0.2em] text-cyan-300">About</div>
            <h2 className="text-3xl font-semibold tracking-tight md:text-4xl">A research-driven personal brand, not just a resume.</h2>
          </div>
          <div className="space-y-5 text-base leading-8 text-neutral-300">
            <p>
              This site is designed as a clean digital home for your story: who you are, what you are building, and where you are going.
            </p>
            <p>
              It works well for students, researchers, founders, and anyone who wants something more elevated than a simple portfolio.
            </p>
          </div>
        </section>

        <section id="work" className="grid gap-6 md:grid-cols-3">
          {[
            {
              title: "Research",
              body: "Highlight labs, posters, publications, or current scientific questions you are working on.",
            },
            {
              title: "Experience",
              body: "Show internships, leadership, venture work, or technical roles with a modern presentation.",
            },
            {
              title: "Interests",
              body: "Include biotech, neurotech, healthcare, entrepreneurship, or any themes you want people to remember.",
            },
          ].map((item) => (
            <div key={item.title} className="rounded-[1.75rem] border border-white/10 bg-white/5 p-6 backdrop-blur">
              <div className="mb-3 text-xl font-semibold">{item.title}</div>
              <p className="text-sm leading-7 text-neutral-400">{item.body}</p>
            </div>
          ))}
        </section>

        <section id="projects">
          <div className="mb-8 flex items-end justify-between gap-6">
            <div>
              <div className="mb-3 text-sm uppercase tracking-[0.2em] text-violet-300">Selected Projects</div>
              <h2 className="text-3xl font-semibold tracking-tight md:text-4xl">Things worth showing.</h2>
            </div>
          </div>
          <div className="grid gap-6 md:grid-cols-3">
            {[
              {
                name: "Neural Data Analysis",
                desc: "A section for signal processing, biomarker discovery, or brain-computer interface related work.",
                tag: "Neurotech",
              },
              {
                name: "Biotech Thesis Map",
                desc: "A place to explain your scientific interests, translational questions, and where you want to go next.",
                tag: "Biology",
              },
              {
                name: "Venture + Science",
                desc: "Show how you evaluate startups, markets, and scientific platforms with technical depth.",
                tag: "VC",
              },
            ].map((project) => (
              <div key={project.name} className="group rounded-[1.75rem] border border-white/10 bg-gradient-to-b from-white/8 to-white/0 p-6 transition hover:-translate-y-1 hover:border-white/20">
                <div className="mb-4 inline-flex rounded-full border border-white/10 px-3 py-1 text-xs text-neutral-300">
                  {project.tag}
                </div>
                <div className="text-xl font-semibold">{project.name}</div>
                <p className="mt-3 text-sm leading-7 text-neutral-400">{project.desc}</p>
              </div>
            ))}
          </div>
        </section>

        <section className="grid gap-6 md:grid-cols-[0.9fr_1.1fr]">
          <div className="rounded-[2rem] border border-white/10 bg-white/5 p-8">
            <div className="mb-3 text-sm uppercase tracking-[0.2em] text-cyan-300">Snapshot</div>
            <h3 className="text-2xl font-semibold tracking-tight">Quick profile</h3>
            <div className="mt-6 space-y-4 text-sm text-neutral-300">
              <div>
                <div className="text-neutral-500">Based in</div>
                <div>Atlanta, GA</div>
              </div>
              <div>
                <div className="text-neutral-500">Focus areas</div>
                <div>Neuroscience, Biotech, Data Science</div>
              </div>
              <div>
                <div className="text-neutral-500">Style</div>
                <div>Analytical, research-driven, future-facing</div>
              </div>
            </div>
          </div>

          <div className="rounded-[2rem] border border-white/10 bg-black/20 p-8">
            <div className="mb-3 text-sm uppercase tracking-[0.2em] text-violet-300">Why this works</div>
            <h3 className="text-2xl font-semibold tracking-tight">Minimal layout, strong identity.</h3>
            <p className="mt-5 max-w-2xl text-base leading-8 text-neutral-300">
              This design gives you a polished personal website you can later customize with your photo, CV, publications, social links, project cards, blog posts, or application materials.
            </p>
          </div>
        </section>

        <section id="contact" className="rounded-[2rem] border border-white/10 bg-gradient-to-r from-cyan-500/10 via-blue-500/10 to-violet-500/10 p-8 md:p-10">
          <div className="max-w-3xl">
            <div className="mb-3 text-sm uppercase tracking-[0.2em] text-cyan-300">Contact</div>
            <h2 className="text-3xl font-semibold tracking-tight md:text-4xl">Let’s build something meaningful.</h2>
            <p className="mt-5 text-base leading-8 text-neutral-300">
              Add your email, LinkedIn, CV link, or a short message here. This section is designed to convert the website from a static page into a real professional hub.
            </p>
            <div className="mt-8 flex flex-wrap gap-4">
              <a href="mailto:yourname@email.com" className="rounded-2xl bg-white px-6 py-3 text-sm font-medium text-neutral-950 transition hover:-translate-y-0.5">
                Email Me
              </a>
              <a href="#" className="rounded-2xl border border-white/15 px-6 py-3 text-sm font-medium text-white transition hover:bg-white/10">
                LinkedIn
              </a>
            </div>
          </div>
        </section>
      </main>
    </div>
  );
}
# Out:
#   Cell In[2], line 20
#     Biology · Neuroscience · Data Science
#             ^
# SyntaxError: invalid character '·' (U+00B7)

# %%
big_city = ["Milwaukee", "Atlanta", "Wilmington", "Chicago", "Portland"]

state_dict_2 = {"state_id" : state_id, "largest_city" : big_city, "year_admitted" : admit_date}

df_cities = pd.DataFrame(state_dict_2)

display(df_cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 big_city = ["Milwaukee", "Atlanta", "Wilmington", "Chicago", "Portland"]
# ----> 3 state_dict_2 = {"state_id" : state_id, "largest_city" : big_city, "year_admitted" : admit_date}
#       5 df_cities = pd.DataFrame(state_dict_2)
#       7 display(df_cities)
#
# NameError: name 'state_id' is not defined

# %% [markdown]
# <font size = "4">
#
# - You can now experiment using ``pd.merge`` with the two DataFrames, ``df_states`` and ``df_cities``.
#
# - It's easier to experiment with these small DataFrames, rather than large data frames created using .csv files from large datasets
#
# - You can make up your own small datasets (even nonsensical ones) using dictionaries. This can be helpful when experimenting with many operations on Pandas DataFrames.
